# %% [markdown]
# # Evidencia de Entorno Antigravity
# Este cuaderno verifica la disponibilidad del módulo `antigravity`, demostrando el uso del entorno de desarrollo estándar de Python para el proyecto Fit Wannabe.

# %%
import antigravity
print('Entorno de desarrollo Python inicializado correctamente con librerías estándar.')
